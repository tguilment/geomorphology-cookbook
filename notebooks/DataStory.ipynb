# %% [markdown]
# # Data Story

# %% [markdown]
# The data used in this project come from the work presented in (Huang _et al._, 2023) _Rule-based semi-automated tools for mapping seabed morphology from bathymetry data_ available at
# [https://www.frontiersin.org/journals/marine-science/articles/10.3389/fmars.2023.1236788/full](https://www.frontiersin.org/journals/marine-science/articles/10.3389/fmars.2023.1236788/full).
#
# They were acquired during ship multibeam echosounder surveys, processed with CARIS HIPS/SIPS, and gridded to metre-scale raster surfaces. The original GA-SaMMT package stores its sample data in three File Geodatabases:
#
# - `Gifford.gdb`
# - `Oceanic_Shoals.gdb`
# - `Points_Cloates.gdb`
#
# The project uses the GeoTIFF converted version:
#
# - `gifford_bathy.tif`
# - `os_bathy.tif`
# - `pc_bathy.tif`
#
# | Cookbook data | Area | Acquisition and processing summary | Grid resolution |
# |---|---|---|---:|
# | `pc_bathy.tif` | Point Cloates Shelf, offshore Western Australia | Acquired in 2008 during survey SOL4769 using a Kongsberg EM3002 multibeam echosounder; processed with CARIS HIPS/SIPS v6.1 | 3 m |
# | `os_bathy.tif` | Oceanic Shoals / Bonaparte Basin, Timor Sea | Collected in 2012 during survey GA0339/SOL5650 using a Kongsberg EM3002D multibeam echosounder; processed with CARIS HIPS/SIPS v7.1 | 2 m |
# | `gifford_bathy.tif` | Gifford Seamounts, Gifford Marine Park, Tasman Sea | Compiled from two multibeam surveys: GA TAN0713 in 2007 using a Kongsberg EM300, and a GA/JAMSTEC survey in 2017 using a Kongsberg 12 kHz deep-water multibeam system; processed with CARIS HIPS/SIPS v7.1 | 50 m |
#
# The Gifford Seamounts grid represents a deeper-water setting than the shelf examples. The case study is centred around 26.79° S, 146.82° E, offshore eastern Australia, and covers water depths from approximately 250 m to 3,500 m. The area contains two seamounts, with ridges and valley-like bedforms on their flat tops and flanks.

# %% [markdown]
# :::{note} Original tools and data samples...
# :class:dropdown
# The associated ArcGIS Pro tools and dataset samples are available [here](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/146832).
# :::
#
# :::{seealso} Full dataset with all datalinks...
# :class:dropdown
# As stated in the article:
# _The datasets presented in this study can be found in online repositories. The names of the repository/repositories and accession number(s) can be found below:
# Bynoe Harbour: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/144556](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/144556);
# Bonaparte Shelf: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/74866](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/74866);
# Bonaparte Basin: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/79006](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/79006);
# Leveque Shelf: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/83727](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/83727);
# Point Cloates Shelf: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/72005](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/72005);
# Broken Ridge: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/82625](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/82625);
# Tasmanian Seamounts: [https://doi.org/10.25919/qan1-qj27](https://doi.org/10.25919/qan1-qj27);
# Gifford Seamounts: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/121193](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/121193);
# Sabrina Slope: [https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/144481](https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/144481)._
# :::
